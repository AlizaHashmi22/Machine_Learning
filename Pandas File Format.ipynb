# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('employee data.xlsx')

# %%
df.head()
# Out:
#           Employee       Location     Sex  Salary Date Hired  Exempt  \
# 0    Krista Orcutt   Pennsylvania  Female   54176 1991-10-22   False
# 1        Cora Soto  Massachusetts  Female   58120 1992-01-15    True
# 2     James Millen     Washington    Male   26135 1992-05-25   False
# 3  Tara Applewhite     California  Female   80274 1992-05-30    True
# 4       Devin Lear  Massachusetts    Male   43532 1992-06-29   False
#
#    Unnamed: 6  Unnamed: 7
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %%
df = df.drop(columns=['Unnamed: 6','Unnamed: 7'])
df.head()
# Out:
#           Employee       Location     Sex  Salary Date Hired  Exempt
# 0    Krista Orcutt   Pennsylvania  Female   54176 1991-10-22   False
# 1        Cora Soto  Massachusetts  Female   58120 1992-01-15    True
# 2     James Millen     Washington    Male   26135 1992-05-25   False
# 3  Tara Applewhite     California  Female   80274 1992-05-30    True
# 4       Devin Lear  Massachusetts    Male   43532 1992-06-29   False

# %%
df['Sex'].value_counts()
# Out:
# Sex
# Male      224
# Female    176
# Name: count, dtype: int64

# %%
population_gender=df.groupby(['Sex','Location']).size()

# %%
population_gender
# Out:
# Sex     Location
# Female  Arizona           5
#         California       44
#         Massachusetts    43
#         New York         51
#         Pennsylvania     17
#         Washington       16
# Male    Arizona          15
#         California       64
#         Massachusetts    47
#         New York         40
#         Pennsylvania     29
#         Washington       29
# dtype: int64

# %%
df['Location'].value_counts()
# Out:
# Location
# California       108
# New York          91
# Massachusetts     90
# Pennsylvania      46
# Washington        45
# Arizona           20
# Name: count, dtype: int64

# %%
Massachusetts_count=df[df['Location']=="Massachusetts"].shape[0]

# %%
Massachusetts_count
# Out:
# 90

# %%
df.query("Location=='Massachusetts' and Sex=='Female'")
# Out:
#                   Employee       Location     Sex  Salary Date Hired  Exempt
# 1                Cora Soto  Massachusetts  Female   58120 1992-01-15    True
# 17            Kimberly Vos  Massachusetts  Female   57568 1993-03-18    True
# 28             PhyllisTodd  Massachusetts  Female   23142 1993-10-24   False
# 33            Ethel Sexton  Massachusetts  Female   63519 1994-02-22    True
# 35              Amy Fetter  Massachusetts  Female   23778 1994-05-27   False
# 41              Carol Wood  Massachusetts  Female   38660 1994-09-08   False
# 42   Christine Poundsworth  Massachusetts  Female   30225 1994-10-03   False
# 45         Karyn Hernandez  Massachusetts  Female   67208 1994-10-25    True
# 60       Shirley Henderson  Massachusetts  Female   44550 1995-08-28   False
# 64            Rosa Johnson  Massachusetts  Female   84084 1995-10-05    True
# 75          Lori Q. Waters  Massachusetts  Female   42607 1996-05-11   False
# ...

# %%
df.query("Location=='Massachusetts' and Sex=='Female'").shape[0]
# Out:
# 43

# %%
df.query("Location=='Massachusetts' and (Sex=='Female' or Salary> 50000) ").shape[0]
# Out:
# 62

# %%
df.query("Location=='Massachusetts' and (Sex=='Female' and Salary> 50000) ").shape[0]
# Out:
# 20

# %%
df.query("(Location=='Massachusetts' and Sex=='Female') or Salary> 50000 ").shape[0]
# Out:
# 200

# %%
df1=pd.read_json('iris.json')

# %%
df1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
url="https://www.fdic.gov/bank-failures/failed-bank-list"
df2=pd.read_html(url)

# %%
df2
# Out:
# [                               Bank Name           City         State   Cert  \
#  0           The Santa Anna National Bank     Santa Anna         Texas   5520
#  1                   Pulaski Savings Bank        Chicago      Illinois  28611
#  2     The First National Bank of Lindsay        Lindsay      Oklahoma   4134
#  3  Republic First Bank dba Republic Bank   Philadelphia  Pennsylvania  27332
#  4                          Citizens Bank       Sac City          Iowa   8758
#  5               Heartland Tri-State Bank        Elkhart        Kansas  25851
#  6                    First Republic Bank  San Francisco    California  59017
#  7                         Signature Bank       New York      New York  57053
#  8                    Silicon Valley Bank    Santa Clara    California  24735
#  9                      Almena State Bank         Almena        Kansas  15426
#
#                   Acquiring Institution      Closing Date  Fund  Sort ascending
# ...

# %%
df2[0]
# Out:
#                                Bank Name           City         State   Cert  \
# 0           The Santa Anna National Bank     Santa Anna         Texas   5520
# 1                   Pulaski Savings Bank        Chicago      Illinois  28611
# 2     The First National Bank of Lindsay        Lindsay      Oklahoma   4134
# 3  Republic First Bank dba Republic Bank   Philadelphia  Pennsylvania  27332
# 4                          Citizens Bank       Sac City          Iowa   8758
# 5               Heartland Tri-State Bank        Elkhart        Kansas  25851
# 6                    First Republic Bank  San Francisco    California  59017
# 7                         Signature Bank       New York      New York  57053
# 8                    Silicon Valley Bank    Santa Clara    California  24735
# 9                      Almena State Bank         Almena        Kansas  15426
#
#                  Acquiring Institution      Closing Date  Fund  Sort ascending
# ...

# %%
url2="https://www.sbp.org.pk/careers/status.asp"
df3=pd.read_html(url2)
df3
# Out:
# [                                                   0   1
#  0                                                NaN NaN
#  1                                                NaN NaN
#  2                                                NaN NaN
#  3                                                NaN NaN
#  4  Jobs & Careers  Raast Payments Pakistan S.No. ... NaN
#  5  Home  About SBP  Publications  Economic Data  ... NaN,
#      0   1   2
#  0 NaN NaN NaN,
#      0   1
#  0 NaN NaN,
#      0   1
#  0 NaN NaN,
#                                                     0   1
#  0                                                NaN NaN
#  1                                                NaN NaN
#  2                                                NaN NaN
#  3  Jobs & Careers  Raast Payments Pakistan S.No. ... NaN,
#                                                     0   1
#  0                                                NaN NaN
#  1                                                NaN NaN
# ...

# %%
df3[0]
# Out:
#                                                    0   1
# 0                                                NaN NaN
# 1                                                NaN NaN
# 2                                                NaN NaN
# 3                                                NaN NaN
# 4  Jobs & Careers  Raast Payments Pakistan S.No. ... NaN
# 5  Home  About SBP  Publications  Economic Data  ... NaN

# %%
df3[12]
# Out:
#         0                                                  1              2  \
# 0   S.No.                                          Positions  Advertisement
# 1       1            Banking Policy & Regulations Department     Click Here
# 2       2                   Cyber Risk Management Department     Click Here
# 3       3                          Cyber Security Department     Click Here
# 4       4          Museum, Art Gallery & Archives Department     Click Here
# 5       5                         Monetary Policy Department     Click Here
# 6       6  Contractual positions in External Communicatio...     Click Here
# 7       7               Assistant Director (OG-2) - Archives     Click Here
# 8       8                  Economic Policy Review Department     Click Here
# 9       9                                Research Department     Click Here
# 10     10                         Additional Director (OG-6)     Click Here
# ...

# %%
tables=pd.read_html(url2)
len(tables)
# Out:
# 15

# %%
tables
# Out:
# [                                                   0   1
#  0                                                NaN NaN
#  1                                                NaN NaN
#  2                                                NaN NaN
#  3                                                NaN NaN
#  4  Jobs & Careers  Raast Payments Pakistan S.No. ... NaN
#  5  Home  About SBP  Publications  Economic Data  ... NaN,
#      0   1   2
#  0 NaN NaN NaN,
#      0   1
#  0 NaN NaN,
#      0   1
#  0 NaN NaN,
#                                                     0   1
#  0                                                NaN NaN
#  1                                                NaN NaN
#  2                                                NaN NaN
#  3  Jobs & Careers  Raast Payments Pakistan S.No. ... NaN,
#                                                     0   1
#  0                                                NaN NaN
#  1                                                NaN NaN
# ...

# %%
import sqlite3

# %%
conn=sqlite3.connect('Chinook_Sqlite.sqlite')

# %%
conn

# %%
pd.read_sql("SELECT name FROM sqlite_master WHERE type='table';",conn)
# Out:
#              name
# 0           Album
# 1          Artist
# 2        Customer
# 3        Employee
# 4           Genre
# 5         Invoice
# 6     InvoiceLine
# 7       MediaType
# 8        Playlist
# 9   PlaylistTrack
# 10          Track

# %%
album=pd.read_sql("SELECT * FROM Album",conn)

# %%
album
# Out:
#      AlbumId                                              Title  ArtistId
# 0          1              For Those About To Rock We Salute You         1
# 1          2                                  Balls to the Wall         2
# 2          3                                  Restless and Wild         2
# 3          4                                  Let There Be Rock         1
# 4          5                                           Big Ones         3
# ..       ...                                                ...       ...
# 342      343                             Respighi:Pines of Rome       226
# 343      344  Schubert: The Late String Quartets & String Qu...       272
# 344      345                                Monteverdi: L'Orfeo       273
# 345      346                              Mozart: Chamber Music       274
# 346      347  Koyaanisqatsi (Soundtrack from the Motion Pict...       275
#
# [347 rows x 3 columns]

# %%
playlist=pd.read_sql("SELECT * FROM PlaylistTrack",conn)

# %%
playlist
# Out:
#       PlaylistId  TrackId
# 0              1     3402
# 1              1     3389
# 2              1     3390
# 3              1     3391
# 4              1     3392
# ...          ...      ...
# 8710          17     2094
# 8711          17     2095
# 8712          17     2096
# 8713          17     3290
# 8714          18      597
#
# [8715 rows x 2 columns]
